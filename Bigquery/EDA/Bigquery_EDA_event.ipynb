# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
users = pd.read_csv('/Users/t2023-m0017/Desktop/실습/프로젝트/최종프로젝트/3차/users.csv')
events = pd.read_csv( '/Users/t2023-m0017/Desktop/실습/프로젝트/최종프로젝트/3차/events.csv')
order_items = pd.read_csv( '/Users/t2023-m0017/Desktop/실습/프로젝트/최종프로젝트/3차/order_items.csv')
products = pd.read_csv('/Users/t2023-m0017/Desktop/실습/프로젝트/최종프로젝트/3차/products.csv')

# %%
events.head()
# Out:
#         id  user_id  sequence_number                            session_id  \
# 0  2198523      NaN                3  83889ed2-2adc-4b9a-af5d-154f6998e778
# 1  1773216      NaN                3  7a3fc3f2-e84f-44fe-8876-eff76741f7a3
# 2  2380515      NaN                3  13d9b2fb-eee1-43fd-965c-267b38dd7125
# 3  2250597      NaN                3  96f1d44e-9621-463c-954c-d8deb7fffe7f
# 4  1834446      NaN                3  d09dce10-a7cb-47d3-a9af-44975566fa03
#
#                   created_at       ip_address          city      state  \
# 0  2021-06-17 17:30:00+00:00    138.143.9.202     São Paulo  São Paulo
# 1  2020-08-07 08:41:00+00:00    85.114.141.79  Santa Isabel  São Paulo
# 2  2021-02-15 18:48:00+00:00  169.250.255.132     Mairiporã  São Paulo
# 3  2022-03-30 10:56:00+00:00   137.25.222.160       Cajamar  São Paulo
# 4  2019-09-05 01:18:00+00:00    161.114.4.174     São Paulo  São Paulo
#
#   postal_code browser traffic_source      uri event_type
# ...

# %%
users.head()
# Out:
#       id   first_name last_name                           email  age gender  \
# 0    457      Timothy      Bush         timothybush@example.net   65      M
# 1   6578    Elizabeth  Martinez   elizabethmartinez@example.com   34      F
# 2  36280  Christopher   Mendoza  christophermendoza@example.net   13      M
# 3  60193        Jimmy    Conner         jimmyconner@example.com   64      M
# 4  64231      Natasha    Wilson       natashawilson@example.net   25      F
#
#   state                street_address postal_code        city country  \
# 0  Acre           87620 Johnson Hills   69917-400  Rio Branco  Brasil
# 1  Acre             1705 Nielsen Land   69917-400  Rio Branco  Brasil
# 2  Acre      125 Turner Isle Apt. 264   69917-400  Rio Branco  Brasil
# 3  Acre     0966 Jose Branch Apt. 008   69917-400  Rio Branco  Brasil
# 4  Acre  20798 Phillip Trail Apt. 392   69917-400  Rio Branco  Brasil
#
#    latitude  longitude traffic_source                 created_at
# ...

# %%
users[users['id']==45469]
# Out:
#           id first_name last_name                        email  age gender  \
# 16082  45469    Abigail  Johnston  abigailjohnston@example.com   25      F
#
#                      state              street_address postal_code  \
# 16082  Centre-Val de Loire  5768 Lang Corner Suite 804       37530
#
#                        city country   latitude  longitude traffic_source  \
# 16082  Souvigny-de-Touraine  France  47.451214   1.020906        Organic
#
#                       created_at
# 16082  2019-09-01 03:01:00+00:00

# %%
pd.set_option('display.max_columns', None)
events_user_id_45469 = events[events['user_id']==45469].sort_values(by = 'created_at')

# %%
events_user_id_45469
# Out:
#              id  user_id  sequence_number  \
# 808641   593944  45469.0                1
# 1424988  593945  45469.0                2
# 1755726  593946  45469.0                3
# 1394306  593947  45469.0                4
# 246282   593948  45469.0                5
#
#                                    session_id                 created_at  \
# 808641   6438ad77-15d3-4b93-ad96-fac125d1f792  2021-10-06 23:39:01+00:00
# 1424988  6438ad77-15d3-4b93-ad96-fac125d1f792  2021-10-06 23:39:56+00:00
# 1755726  6438ad77-15d3-4b93-ad96-fac125d1f792  2021-10-06 23:42:45+00:00
# 1394306  6438ad77-15d3-4b93-ad96-fac125d1f792  2021-10-06 23:44:08+00:00
# 246282   6438ad77-15d3-4b93-ad96-fac125d1f792  2021-10-06 23:44:41+00:00
#
#             ip_address                  city                state postal_code  \
# 808641   222.136.183.4  Souvigny-de-Touraine  Centre-Val de Loire       37530
# 1424988  222.136.183.4  Souvigny-de-Touraine  Centre-Val de Loire       37530
# ...

# %%
events_user_id_45469[['uri','event_type']].value_counts()
# Out:
# uri                                                  event_type
# /cart                                                cart          1
# /department/women/category/outerwear&coats/brand/sz  department    1
# /home                                                home          1
# /product/8770                                        product       1
# /purchase                                            purchase      1
# dtype: int64

# %%
order_items[order_items['user_id']==45469]
# Out:
#            id  order_id  user_id  product_id  inventory_item_id    status  \
# 141398  82517     56760    45469        8770             222684  Complete
#
#                        created_at                 shipped_at  \
# 141398  2021-10-06 23:45:56+00:00  2021-10-07 23:23:00+00:00
#
#                      delivered_at returned_at  sale_price
# 141398  2021-10-12 21:34:00+00:00         NaN   76.989998

# %%
products[products['id']==8770]
# events에 있던 uri : /department/women/category/outerwear&coats/brand/sz
# Out:
#          id       cost           category  \
# 24524  8770  33.567639  Outerwear & Coats
#
#                                                     name brand  retail_price  \
# 24524  SZ New Fashion Women Woolen Warm Winter Coat L...    SZ     76.989998
#
#       department                               sku  distribution_center_id
# 24524      Women  BE4E02AC094A09D32E3C09B34F3883A2                       9

# %% [markdown]
# ### event 컬럼 분석
#     # 2.events.csv
#     # 칼럼:
#     # id: 각 이벤트에 대한 고유 식별자.
#     # user_id: 이벤트와 관련된 사용자의 식별자.
#     # sequence_number: 이벤트의 시퀀스 번호.
#     # session_id: 이벤트가 발생한 세션의 식별자.
#     # created_at: 이벤트가 언제 발생했는지를 나타내는 타임스탬프.
#     # ip_address: 이벤트가 시작된 IP 주소.
#     # city: 사건이 발생한 도시.
#     # state: 사건이 발생한 곳.
#     # postal_code: 행사 장소의 우편 번호.
#     # browser: 행사 중에 사용된 웹 브라우저.
#     # traffic_source: 행사로 이어지는 교통의 원천.
#     # uri: 이벤트와 관련된 균일한 자원 식별자.
#     # event_type: 기록된 이벤트 유형.

# %%
events.columns
# Out:
# Index(['id', 'user_id', 'sequence_number', 'session_id', 'created_at',
#        'ip_address', 'city', 'state', 'postal_code', 'browser',
#        'traffic_source', 'uri', 'event_type'],
#       dtype='object')

# %%
events['uri'].value_counts()
#purchase 구매자 :181759 -> order_items(구입내역이 있는)의 데이터 수와 동일
# Out:
# /cart                                                                  595994
# /purchase                                                              181759
# /cancel                                                                125568
# /home                                                                   87712
# /department/women/category/maternity/brand/motherhoodmaternity           3354
#                                                                         ...
# /department/women/category/fashionhoodies&sweatshirts/brand/citizen         6
# /department/women/category/tops&tees/brand/blackmarket-lowbrow              6
# /product/11264                                                              6
# /department/men/category/outerwear&coats/brand/toesonthenose                5
# /department/women/category/sweaters/brand/hotfromhollywood                  3
# Name: uri, Length: 35530, dtype: int64

# %%
order_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181759 entries, 0 to 181758
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 181759 non-null  int64
#  1   order_id           181759 non-null  int64
#  2   user_id            181759 non-null  int64
#  3   product_id         181759 non-null  int64
#  4   inventory_item_id  181759 non-null  int64
#  5   status             181759 non-null  object
#  6   created_at         181759 non-null  object
#  7   shipped_at         118281 non-null  object
#  8   delivered_at       63841 non-null   object
#  9   returned_at        18232 non-null   object
#  10  sale_price         181759 non-null  float64
# dtypes: float64(1), int64(5), object(5)
# memory usage: 15.3+ MB

# %%
events_user_80952 = events[events['user_id'] == 80952].sort_values(by = 'created_at')

# %%
events_user_80952[events_user_80952['session_id']=='3ab02b7b-a036-4be4-95fb-caa65105af13']
# Out:
#               id  user_id  sequence_number  \
# 1646790  1058947  80952.0                1
# 512067   1058948  80952.0                2
# 573263   1058949  80952.0                3
# 653978   1058950  80952.0                4
# 2249074  1058951  80952.0                5
# 1045700  1058952  80952.0                6
# 1622131  1058953  80952.0                7
# 2026415  1058954  80952.0                8
# 1665463  1058955  80952.0                9
# 1522592  1058956  80952.0               10
# 2373065  1058957  80952.0               11
# 1640632  1058958  80952.0               12
# 494857   1058959  80952.0               13
#
#                                    session_id                 created_at  \
# 1646790  3ab02b7b-a036-4be4-95fb-caa65105af13  2019-11-11 01:39:37+00:00
# 512067   3ab02b7b-a036-4be4-95fb-caa65105af13  2019-11-11 01:39:49+00:00
# 573263   3ab02b7b-a036-4be4-95fb-caa65105af13  2019-11-11 01:42:40+00:00
# ...

# %%
#pd.set_option('display.max_rows', None)
#events_user_80952 #148개
#events_user_80952['id'].nunique() #148개 -> 인덱스 같은 기능
#events_user_80952['sequence_number'].value_counts() # 동일한 섹션 아이디에 대한 활동 수(event수) 13개*3 + 10*3 +7*2
events_user_80952['session_id'].value_counts() # 고유카운트 13개, 13(event)*8(섹션수) + 10*3 +7*2
# Out:
# 3ab02b7b-a036-4be4-95fb-caa65105af13    13
# 7b0e4561-5da6-4172-b376-45787e256915    13
# bbeecfd0-488c-4840-9269-1a17cb6b9188    13
# ff598998-69d1-40d0-8b2f-86ae6e1677ce    13
# 0455eb1b-fa6a-49f8-80a8-39fab0b7d399    13
# 592af389-4de3-4b49-b1a5-cbaf43f36521    13
# 6e542211-2017-4abc-b92e-40432c013b55    13
# 9e442c91-98a7-439c-a5ff-7f41b64ba369    13
# 9b4c4751-024d-4b47-9346-0ee8f158ba42    10
# ecccfafe-c297-425b-b333-8e0659ece188    10
# b425060f-c261-4ca9-b3a4-deceb82ed455    10
# f786262c-6d45-442b-bde7-ce2af39724dd     7
# 5fd06231-7550-4ef0-80a1-058aca1bee61     7
# Name: session_id, dtype: int64

# %% [markdown]
# ### USER 컬럼분석
#  -> 회원가입 정보
# 7.users.csv
#
#     # 칼럼:
#     # id: 각 사용자에 대한 고유 식별자.
#     # first_name: 사용자의 이름.
#     # last_name: 사용자의 성.
#     # email: 사용자의 이메일 주소.
#     # age: 사용자의 나이.
#     # gender: 사용자의 성별.
#     # state: 사용자가 어디에 있는지 상태.
#     # street_address: 사용자의 거리 주소.
#     # postal_code: 사용자의 우편 번호.
#     # city: 사용자가 위치한 도시.
#     # country: 사용자가 위치한 국가.
#     # latitude: 사용자의 위도 좌표.
#     # longitude: 사용자의 경도 좌표.
#     # traffic_source: 사용자에게 이어지는 트래픽의 출처.
#     # created_at: 사용자 계정이 생성되었을 때를 나타내는 타임스탬프

# %%
users.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'age', 'gender', 'state',
#        'street_address', 'postal_code', 'city', 'country', 'latitude',
#        'longitude', 'traffic_source', 'created_at'],
#       dtype='object')

# %%
users.head(10)
# Out:
#       id   first_name  last_name                           email  age gender  \
# 0    457      Timothy       Bush         timothybush@example.net   65      M
# 1   6578    Elizabeth   Martinez   elizabethmartinez@example.com   34      F
# 2  36280  Christopher    Mendoza  christophermendoza@example.net   13      M
# 3  60193        Jimmy     Conner         jimmyconner@example.com   64      M
# 4  64231      Natasha     Wilson       natashawilson@example.net   25      F
# 5  72187       Andrea     Bryant        andreabryant@example.org   47      F
# 6  22528        Keith    Barnett        keithbarnett@example.com   64      M
# 7  34417       Joanne  Mcpherson     joannemcpherson@example.com   28      F
# 8  50098          Ian      Burke            ianburke@example.net   52      M
# 9  63352        David     Orozco         davidorozco@example.org   18      M
#
#   state                street_address postal_code            city country  \
# ...

# %%
# traffic_source -> 해당 사이트를 알게된 경로
users['traffic_source'].value_counts()
# Out:
# Search      70075
# Organic     15110
# Facebook     5816
# Email        4947
# Display      4052
# Name: traffic_source, dtype: int64

# %%
# 테이블조인 : events와 users -> event에는 uesrID가 없는 데이터 존재
# 컬럼 중복 : city, state, postal_code, traffic_source
users.rename(columns = {'id':'user_id'},inplace = True)
user_event = pd.merge(users, events, on='user_id', how = 'outer')

# %%
user_event.head()
# Out:
#    user_id first_name last_name                    email   age gender state_x  \
# 0    457.0    Timothy      Bush  timothybush@example.net  65.0      M    Acre
# 1    457.0    Timothy      Bush  timothybush@example.net  65.0      M    Acre
# 2    457.0    Timothy      Bush  timothybush@example.net  65.0      M    Acre
# 3    457.0    Timothy      Bush  timothybush@example.net  65.0      M    Acre
# 4    457.0    Timothy      Bush  timothybush@example.net  65.0      M    Acre
#
#         street_address postal_code_x      city_x country  latitude  longitude  \
# 0  87620 Johnson Hills     69917-400  Rio Branco  Brasil -9.945568  -67.83561
# 1  87620 Johnson Hills     69917-400  Rio Branco  Brasil -9.945568  -67.83561
# 2  87620 Johnson Hills     69917-400  Rio Branco  Brasil -9.945568  -67.83561
# 3  87620 Johnson Hills     69917-400  Rio Branco  Brasil -9.945568  -67.83561
# 4  87620 Johnson Hills     69917-400  Rio Branco  Brasil -9.945568  -67.83561
#
# ...

# %%
# 전체 데이터 2451919 -> state가 같은 1306292 
#user_event[(user_event['state_x']==user_event['state_y'])]
# state가 다른 경우 1145627
# -> user_id가 없는 경우(비회원)1125671 
user_event[(user_event['state_x']!=user_event['state_y'])][['state_x','state_y']]
# Out:
#         state_x  state_y
# 5          Acre      NaN
# 94         Acre      NaN
# 124        Acre      NaN
# 185        Acre      NaN
# 186        Acre      NaN
# ...         ...      ...
# 2451914     NaN  England
# 2451915     NaN  England
# 2451916     NaN  England
# 2451917     NaN  England
# 2451918     NaN  England
#
# [1145627 rows x 2 columns]

# %%
user_event.info(verbose=True, null_counts=True)
# Out:
# /var/folders/1y/dmb1rjqn7y7ft_t08s501gxm0000gn/T/ipykernel_19939/4167434682.py:1: FutureWarning: null_counts is deprecated. Use show_counts instead
#   user_event.info(verbose=True, null_counts=True)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2451919 entries, 0 to 2451918
# Data columns (total 27 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   user_id           1326248 non-null  float64
#  1   first_name        1326248 non-null  object
#  2   last_name         1326248 non-null  object
#  3   email             1326248 non-null  object
#  4   age               1326248 non-null  float64
#  5   gender            1326248 non-null  object
#  6   state_x           1326248 non-null  object
#  7   street_address    1326248 non-null  object
#  8   postal_code_x     1326248 non-null  object
#  9   city_x            1313875 non-null  object
#  10  country           1326248 non-null  object
# ...

# %%
event.info(verbose=True, null_counts=True)

# %%
2431963 - 1326248
# Out:
# 1105715

# %%
# enevt에서 userid가 없는 경우 -> 1125671 
user_event[user_event['user_id'].isna()]
# Out:
#          user_id first_name last_name email  age gender state_x  \
# 1326248      NaN        NaN       NaN   NaN  NaN    NaN     NaN
# 1326249      NaN        NaN       NaN   NaN  NaN    NaN     NaN
# 1326250      NaN        NaN       NaN   NaN  NaN    NaN     NaN
# 1326251      NaN        NaN       NaN   NaN  NaN    NaN     NaN
# 1326252      NaN        NaN       NaN   NaN  NaN    NaN     NaN
# ...          ...        ...       ...   ...  ...    ...     ...
# 2451914      NaN        NaN       NaN   NaN  NaN    NaN     NaN
# 2451915      NaN        NaN       NaN   NaN  NaN    NaN     NaN
# 2451916      NaN        NaN       NaN   NaN  NaN    NaN     NaN
# 2451917      NaN        NaN       NaN   NaN  NaN    NaN     NaN
# 2451918      NaN        NaN       NaN   NaN  NaN    NaN     NaN
#
#         street_address postal_code_x city_x country  latitude  longitude  \
# 1326248            NaN           NaN    NaN     NaN       NaN        NaN
# ...

# %%
user_event
# Out:
#          user_id first_name last_name                    email   age gender  \
# 0          457.0    Timothy      Bush  timothybush@example.net  65.0      M
# 1          457.0    Timothy      Bush  timothybush@example.net  65.0      M
# 2          457.0    Timothy      Bush  timothybush@example.net  65.0      M
# 3          457.0    Timothy      Bush  timothybush@example.net  65.0      M
# 4          457.0    Timothy      Bush  timothybush@example.net  65.0      M
# ...          ...        ...       ...                      ...   ...    ...
# 2451914      NaN        NaN       NaN                      NaN   NaN    NaN
# 2451915      NaN        NaN       NaN                      NaN   NaN    NaN
# 2451916      NaN        NaN       NaN                      NaN   NaN    NaN
# 2451917      NaN        NaN       NaN                      NaN   NaN    NaN
# 2451918      NaN        NaN       NaN                      NaN   NaN    NaN
#
# ...
